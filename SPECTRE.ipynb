# %%
import sys
import webbrowser

import pyttsx3
import speech_recognition as sr
import datetime
import os
import cv2
import random
from requests import get
import wikipedia
import pywhatkit as kit
import webbrowser
import smtplib




engine = pyttsx3.init('sapi5')
engine.setProperty('volume',    1.5)
engine.setProperty('rate',  200)
voices = engine.getProperty('voices')

engine.setProperty('voices',voices[0].id)
#text to voice
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
    print(audio)
#converting speech to text
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        r.adjust_for_ambient_noise(source)
        audio = r.listen(source, timeout=3, phrase_time_limit=5)
    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f'User said: {query}')
    except Exception as e:
        print("Say that again please...")
        return "None"
    return query

# to whish
def whish():
    hour =int(datetime.datetime.now().hour)
    if hour>=0 and hour<12:
        speak("Good Morning")
        speak("I'm spectre ,how can I help you?")
    elif hour>=12 and hour<18:
        speak("Good Afternoon")
        speak("I'm spectre ,how can I help you?")
    elif hour>=18 and hour<24:
        speak("Good Evening")
        speak("I'm spectre ,how can I help you?")
    else:
        speak("Good Night")
        speak("I'm spectre ,how can I help you?")

def sendEmail(to, content):
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.ehlo()
    server.starttls()
    server.login('mgkmukeshmugan@gmail.com', 'mukesh@007')
    server.sendmail('mgkmukeshmugan@gmail.com', to, content)


def work():
    while True:
        query = takeCommand().lower()
        if 'notepad' in query:
            notepad = "C:\\WINDOWS\\system32\\notepad.exe"
            os.startfile(notepad)
            speak("Notepad opened. What else can I do for you?")
        elif 'browser' in query or 'edge' in query:
            browser = "C:\\Program Files (x86)\\Microsoft\\Edge\\Application\\msedge.exe"
            os.startfile(browser)
            speak("Microsoft Edge opened. What else can I do for you?")
        elif "open camera" in query:
            cap = cv2.VideoCapture(0)
            while True:
                ret, frame = cap.read()
                cv2.imshow('webcam', frame)
                k = cv2.waitKey(50)
                if k % 256 == 27:
                    break
            cap.release()
            cv2.destroyAllWindows()
            speak("Camera feed closed. What else can I do for you?")
        elif "play music" in query:
            music_dir = "C:\\Users\\<NAME>\\Music\\"  # Replace <NAME> with your username
            songs = os.listdir(music_dir)
            for song in songs:
                if song.endswith(".mp3"):
                    os.startfile(os.path.join(music_dir, song))
            speak("Music started. What else can I do for you?")
        elif 'ip address' in query:
            ip = get('https://api.ipify.org').text
            speak(f"Your IP address is {ip}. What else can I do for you?")
        elif 'wikipedia' in query:
            search_query = query.replace("wikipedia", "")
            results = wikipedia.summary(search_query, sentences=5)
            speak("According to Wikipedia")
            speak(results)
        elif 'open youtube' in query:
            webbrowser.open('https://www.youtube.com')
            speak("YouTube opened. What else can I do for you?")
        elif 'play song on youtube' in query:
            speak('what song do you want to play?')
            song=takeCommand()
            kit.playonyt(song)
            
        elif 'linkedin' in query:
            webbrowser.open('https://www.linkedin.com')
            speak("LinkedIn opened. What else can I do for you?")
        elif 'open google' in query:
            speak("What should I search in Google?")
            search_query = takeCommand()
            webbrowser.open(f'https://www.google.com/search?q={search_query}')
            speak("Google search opened. What else can I do for you?")
        elif 'send a message to vasanth' in query:
            speak("What message do you want to send?")
            message_content = takeCommand()
            speak("At what hour do you want to send the message?")
            hour = int(takeCommand())
            speak("At what minute do you want to send the message?")
            minute = int(takeCommand())
            kit.sendwhatmsg('+91 93606 62943', message_content, hour, minute)
            speak("Message sent successfully.")
        elif "send email " in query:
            try:
                speak("What email do you want to send?")
                content = takeCommand().lower()
                speak("At what email do you want to send?")
                email = takeCommand()
                # Implement sendEmail() function or any other email sending method here
                speak("Email sent successfully.")
            except Exception as e:
                print(e)
                speak("Sorry, I can't send email.")
        elif "no thanks" in query:
            speak("Thank you for using SPECTRE.")
            break
        else:
            speak("Sorry, I didn't catch that. Can you please repeat?")
            continue







if __name__ == '__main__':
    whish()
    work()
